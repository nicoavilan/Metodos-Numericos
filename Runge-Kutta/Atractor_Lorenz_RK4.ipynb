# %% [markdown]
# <a href="https://colab.research.google.com/github/nicoavilan/Metodos-Numericos/blob/main/Runge-Kutta/Atractor_Lorenz_RK4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Atractor de Lorenz**

# %% [markdown]
# En esta entrada se genera la solución del sistema de ecuaciones propuesto originalmente por *Edward Lorenz* en su artículo [Deterministic Nonperiodic Flow](https://journals.ametsoc.org/view/journals/atsc/20/2/1520-0469_1963_020_0130_dnf_2_0_co_2.xml?tab_body=pdf) usando el método de Runge-Kutta (RK4).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x,y,z):
  return a*(y-x)

def g(x,y,z):
  return x*(b-z)-y

def j(x,y,z):
  return x*y-c*z

a = 10
b = 28
c = 8/3

tf=50
N=10**4
h=tf/N


t=np.linspace(0,tf,N)
x = [0.1]
y = [0.1]
z = [25]

# Al implementar RK4 para tres ecuaciones difetenciales hay que calcular tres conjuntos de ks' de manera intercalada.

for n in range(N-1):
  kx1 = f(x[n],y[n],z[n])
  ky1 = g(x[n],y[n],z[n])
  kz1 = j(x[n],y[n],z[n])
  kx2 = f(x[n] + h*kx1/2,y[n] + h*ky1/2,z[n] + h*kz1/2)
  ky2 = g(x[n] + h*kx1/2,y[n] + h*ky1/2,z[n] + h*kz1/2)
  kz2 = j(x[n] + h*kx1/2,y[n] + h*ky1/2,z[n] + h*kz1/2)
  kx3 = f(x[n] + h*kx2/2,y[n] + h*ky2/2,z[n] + h*kz2/2)
  ky3 = g(x[n] + h*kx2/2,y[n] + h*ky2/2,z[n] + h*kz2/2)
  kz3 = j(x[n] + h*kx2/2,y[n] + h*ky2/2,z[n] + h*kz2/2)
  kx4 = f(x[n] + h*kx3,y[n] + h*ky3,z[n] + h*kz3)
  ky4 = g(x[n] + h*kx3,y[n] + h*ky3,z[n] + h*kz3)
  kz4 = j(x[n] + h*kx3,y[n] + h*ky3,z[n] + h*kz3)

  x.append(x[n]+(h/6)*(kx1 + 2*kx2 + 2*kx3 + kx4))
  y.append(y[n]+(h/6)*(ky1 + 2*ky2 + 2*ky3 + ky4))
  z.append(z[n]+(h/6)*(kz1 + 2*kz2 + 2*kz3 + kz4))

print("Soluciones calculadas.")
# Out:
# Soluciones calculadas.

# %% [markdown]
# Las gráfica de las soluciones del sistema de ecuaciones es

# %%
plt.plot(t,x,label="x")
plt.plot(t,y,label="y")
plt.plot(t,z,label="z")
plt.legend()
plt.show()

# %% [markdown]
# El resultado más conocido de este sistema se conoce como el **atractor de Lorenz**.

# %%
plt.plot(x,z)
plt.title("Atractor de Lorenz")
plt.xlabel("x")
plt.ylabel("z")
plt.show()

# %% [markdown]
# Las gráficas del otro par de variables es

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(x,y,label="y vs x")
plt.legend()

plt.subplot(1,2,2)
plt.plot(y,z,label="z vs y")
plt.legend()
plt.show()

# %% [markdown]
# Gráfica 3D

# %%
fig = plt.figure(figsize= (8,7))
ax = fig.gca(projection='3d')
ax.plot(x, y, z)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
plt.show()

# %% [markdown]
# Al usar la librería [plotly](https://plotly.com/python/) se puede obtener una gráfica interactiva en la que es posible ver la gráfica 3D desde diferentes perspectivas.

# %% [markdown]
# Cargo la librería plotly

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z, mode='markers',
    marker = dict(
        size=1, # Define el tamaño de cada punto en la gráfica
        color=z, # Ajusta el color de acuerdo a la coordenada z
        colorscale='Viridis'))])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# *Para ver y manipular la gráfica interactiva generada con plotly hay que compilar el código, github no la genera automáticamente.*

# %% [markdown]
# Es muy interesante observar la evolución de las variables para la construcción del **atractor de Lorenz**. Para ello se realiza la siguiente animación

# %%
import matplotlib.animation as animation
from IPython.display import HTML

# %%
fig=plt.figure()
ax=fig.gca()

def actualizar(i):
  ax.clear()

  ax.plot(x[:i], z[:i],'-')
  ax.set_title("Atractor de Lorenz")
  ax.plot(x[i],  z[i],'o',markersize=10,color='r')

# %%
ani=animation.FuncAnimation(fig, actualizar, range(0,N,30), interval=200)
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# La animación se observa al ejecutar el código, GitHub no la genera automáticamente.
